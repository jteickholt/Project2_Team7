# %%
#store the data we get as a dataframe
import pandas as pd

#convert the response as a strcuctured json
import json

#mathematical operations on lists
import numpy as np
import os

# %%
# Import csv files
education_city_data = os.path.join('..','data','data_edu_city.csv')
diversity_city_data = os.path.join('..','data','data_diver_city.csv')
education_state_data = os.path.join('..','data','data_edu_state.csv')
diversity_state_data = os.path.join('..','data','data_diver_state.csv')

# %%
# Create dataframe from the imported csv
education_city_df = pd.read_csv(education_city_data)
diversity_city_df = pd.read_csv(diversity_city_data)
education_state_df = pd.read_csv(education_state_data)
diversity_state_df = pd.read_csv(diversity_state_data)

# %%
# Education City Table

# %%
education_city_df.head(5)
# Out:
#            GEO_ID                          NAME  \
# 0              id          Geographic Area Name
# 1  310M400US13180     Beaver Dam, WI Micro Area
# 2  310M400US14540  Bowling Green, KY Metro Area
# 3  310M400US16180    Carson City, NV Metro Area
# 4  310M400US17980    Columbus, GA-AL Metro Area
#
#                                S1501_C01_001E  \
# 0  Estimate!!Total!!Population 18 to 24 years
# 1                                        6039
# 2                                       24385
# 3                                        4289
# 4                                       31402
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total MOE!!Population 18 to 2...
# 1                                                270
# 2                                               1649
# 3                                                585
# 4                                               1381
#
#                                  S1501_C02_001E  \
# ...

# %%
#keep only fields of interest and assign new names 
edu_city_df=education_city_df[['GEO_ID', 'NAME','S1501_C01_006E','S1501_C01_007E','S1501_C01_007E','S1501_C01_008E','S1501_C01_009E','S1501_C01_010E','S1501_C01_011E','S1501_C01_012E', \
                       'S1501_C01_013E','S1501_C01_014E','S1501_C01_015E']]

# %%
edu_city_df.head(5)
# Out:
#            GEO_ID                          NAME  \
# 0              id          Geographic Area Name
# 1  310M400US13180     Beaver Dam, WI Micro Area
# 2  310M400US14540  Bowling Green, KY Metro Area
# 3  310M400US16180    Carson City, NV Metro Area
# 4  310M400US17980    Columbus, GA-AL Metro Area
#
#                                   S1501_C01_006E  \
# 0  Estimate!!Total!!Population 25 years and over
# 1                                          64427
# 2                                         112195
# 3                                          39809
# 4                                         201128
#
#                                       S1501_C01_007E  \
# 0  Estimate!!Total!!Population 25 years and over!...
# 1                                               1789
# 2                                               7114
# 3                                               2253
# 4                                               6307
#
# ...

# %%
edu_city_df=edu_city_df.rename(columns={'NAME': 'Area Name', 'S1501_C01_006E': 'Total_Population over 25 years old', 'S1501_C01_007E': 'Less than 9th Grade', \
                              'S1501_C01_008E': '9th to 12th (no diploma)', 'S1501_C01_009E': 'High School Diploma', 'S1501_C01_010E': 'Some College (no degree)', \
                              'S1501_C01_011E': 'Associate Degree', 'S1501_C01_012E': 'Bachelor Degree', 'S1501_C01_013E': 'Graduate/Proffesional Degree' , \
                                     'S1501_C01_014E': 'High School Graduate or Higher', 'S1501_C01_015E': 'Bachelor Degree or Higher'})
edu_city_df.head(5)
# Out:
#            GEO_ID                     Area Name  \
# 0              id          Geographic Area Name
# 1  310M400US13180     Beaver Dam, WI Micro Area
# 2  310M400US14540  Bowling Green, KY Metro Area
# 3  310M400US16180    Carson City, NV Metro Area
# 4  310M400US17980    Columbus, GA-AL Metro Area
#
#               Total_Population over 25 years old  \
# 0  Estimate!!Total!!Population 25 years and over
# 1                                          64427
# 2                                         112195
# 3                                          39809
# 4                                         201128
#
#                                  Less than 9th Grade  \
# 0  Estimate!!Total!!Population 25 years and over!...
# 1                                               1789
# 2                                               7114
# 3                                               2253
# 4                                               6307
#
# ...

# %%
# Diversity City Table

# %%
diversity_city_df.head(5)
# Out:
#            GEO_ID                                          NAME  \
# 0              id                          Geographic Area Name
# 1  310M400US10300                         Adrian, MI Micro Area
# 2  310M400US10460                     Alamogordo, NM Micro Area
# 3  310M400US10780                     Alexandria, LA Metro Area
# 4  310M400US12060  Atlanta-Sandy Springs-Roswell, GA Metro Area
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                    98266
# 2                                    66781
# 3                                   153044
# 4                                  5950828
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           *****
# 2                                           *****
# 3                                           *****
# 4                                            2546
#
# ...

# %%
#keep only fields of interest and assign new names 
diver_city_df=diversity_city_df[['GEO_ID', 'NAME','DP05_0037E', 'DP05_0038E','DP05_0039E','DP05_0044E','DP05_0057E','DP05_0071E']]

# %%
diver_city_df.head(5)
# Out:
#            GEO_ID                                          NAME  \
# 0              id                          Geographic Area Name
# 1  310M400US10300                         Adrian, MI Micro Area
# 2  310M400US10460                     Alamogordo, NM Micro Area
# 3  310M400US10780                     Alexandria, LA Metro Area
# 4  310M400US12060  Atlanta-Sandy Springs-Roswell, GA Metro Area
#
#                                           DP05_0037E  \
# 0  Estimate!!RACE!!Total population!!One race!!White
# 1                                              92099
# 2                                              53505
# 3                                             100225
# 4                                            3140829
#
#                                           DP05_0038E  \
# 0  Estimate!!RACE!!Total population!!One race!!Bl...
# 1                                               2261
# 2                                               2225
# ...

# %%
diver_city_df=diver_city_df.rename(columns={'NAME': 'Area Name', 'DP05_0037E': 'White', 'DP05_0038E': 'Black/African American', \
                                      'DP05_0039E': 'American Indian & Alaska Native', 'DP05_0044E': 'Asian' , 'DP05_0057E': 'Some other race', \
                                      'DP05_0071E':'Hispanic/Latino'})
diver_city_df.head(5)
# Out:
#            GEO_ID                                     Area Name  \
# 0              id                          Geographic Area Name
# 1  310M400US10300                         Adrian, MI Micro Area
# 2  310M400US10460                     Alamogordo, NM Micro Area
# 3  310M400US10780                     Alexandria, LA Metro Area
# 4  310M400US12060  Atlanta-Sandy Springs-Roswell, GA Metro Area
#
#                                                White  \
# 0  Estimate!!RACE!!Total population!!One race!!White
# 1                                              92099
# 2                                              53505
# 3                                             100225
# 4                                            3140829
#
#                               Black/African American  \
# 0  Estimate!!RACE!!Total population!!One race!!Bl...
# 1                                               2261
# 2                                               2225
# ...

# %%
# Merge Education by CITY with Diversity by CITY

# %%
city_edu_diver_df=pd.merge(edu_city_df, diver_city_df,on="GEO_ID")

city_edu_diver_df=city_edu_diver_df.drop(columns=["Area Name_y"])
city_edu_diver_df.head()
# Out:
#            GEO_ID                   Area Name_x  \
# 0              id          Geographic Area Name
# 1  310M400US13180     Beaver Dam, WI Micro Area
# 2  310M400US14540  Bowling Green, KY Metro Area
# 3  310M400US16180    Carson City, NV Metro Area
# 4  310M400US17980    Columbus, GA-AL Metro Area
#
#               Total_Population over 25 years old  \
# 0  Estimate!!Total!!Population 25 years and over
# 1                                          64427
# 2                                         112195
# 3                                          39809
# 4                                         201128
#
#                                  Less than 9th Grade  \
# 0  Estimate!!Total!!Population 25 years and over!...
# 1                                               1789
# 2                                               7114
# 3                                               2253
# 4                                               6307
#
# ...

# %%
# Education State Table

# %%
education_state_df.head(5)
# Out:
#         GEO_ID                  NAME  \
# 0           id  Geographic Area Name
# 1  0400000US02                Alaska
# 2  0400000US23                 Maine
# 3  0400000US37        North Carolina
# 4  0400000US29              Missouri
#
#                                S1501_C01_001E  \
# 0  Estimate!!Total!!Population 18 to 24 years
# 1                                       68625
# 2                                      106470
# 3                                      984618
# 4                                      565939
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total MOE!!Population 18 to 2...
# 1                                               1567
# 2                                               1499
# 3                                               8049
# 4                                               5032
#
#                                  S1501_C02_001E  \
# 0  Estimate!!Percent!!Population 18 to 24 years
# ...

# %%
#keep only fields of interest and assign new names 
edu_state_df=education_state_df[['GEO_ID', 'NAME','S1501_C01_006E','S1501_C01_007E','S1501_C01_008E','S1501_C01_009E','S1501_C01_010E','S1501_C01_011E','S1501_C01_012E', \
                       'S1501_C01_013E','S1501_C01_014E','S1501_C01_015E']]

# %%
edu_state_df.head(5)
# Out:
#         GEO_ID                  NAME  \
# 0           id  Geographic Area Name
# 1  0400000US02                Alaska
# 2  0400000US23                 Maine
# 3  0400000US37        North Carolina
# 4  0400000US29              Missouri
#
#                                   S1501_C01_006E  \
# 0  Estimate!!Total!!Population 25 years and over
# 1                                         485353
# 2                                         983382
# 3                                        7102144
# 4                                        4182787
#
#                                       S1501_C01_007E  \
# 0  Estimate!!Total!!Population 25 years and over!...
# 1                                              12023
# 2                                              25361
# 3                                             305097
# 4                                             119915
#
#                                       S1501_C01_008E  \
# 0  Estimate!!Total!!Population 25 years and over!...
# ...

# %%
edu_state_df=edu_state_df.rename(columns={'NAME': 'Area Name', 'S1501_C01_006E': 'Total_Population over 25 years old', 'S1501_C01_007E': 'Less than 9th Grade', \
                              'S1501_C01_008E': '9th to 12th (no diploma)', 'S1501_C01_009E': 'High School Diploma', 'S1501_C01_010E': 'Some College (no degree)', \
                              'S1501_C01_011E': 'Associate Degree', 'S1501_C01_012E': 'Bachelor Degree', 'S1501_C01_013E': 'Graduate/Proffesional Degree' , \
                              'S1501_C01_014E': 'High School Graduate or Higher', 'S1501_C01_015E': 'Bachelor Degree or Higher'})
edu_state_df.head(5)
# Out:
#         GEO_ID             Area Name  \
# 0           id  Geographic Area Name
# 1  0400000US02                Alaska
# 2  0400000US23                 Maine
# 3  0400000US37        North Carolina
# 4  0400000US29              Missouri
#
#               Total_Population over 25 years old  \
# 0  Estimate!!Total!!Population 25 years and over
# 1                                         485353
# 2                                         983382
# 3                                        7102144
# 4                                        4182787
#
#                                  Less than 9th Grade  \
# 0  Estimate!!Total!!Population 25 years and over!...
# 1                                              12023
# 2                                              25361
# 3                                             305097
# 4                                             119915
#
#                             9th to 12th (no diploma)  \
# 0  Estimate!!Total!!Population 25 years and over!...
# ...

# %%
# Diversity State Table

# %%
diversity_state_df.head(5)
# Out:
#         GEO_ID                  NAME                               DP05_0001E  \
# 0           id  Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1  0400000US17              Illinois                                 12741080
# 2  0400000US19                  Iowa                                  3156145
# 3  0400000US29              Missouri                                  6126452
# 4  0400000US32                Nevada                                  3034392
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           *****
# 2                                           *****
# 3                                           *****
# 4                                           *****
#
#                                        DP05_0001PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total population
# 1                                         12741080
# ...

# %%
#keep only fields of interest and assign new names 
diver_state_df=diversity_state_df[['GEO_ID', 'NAME','DP05_0037E', 'DP05_0038E','DP05_0039E','DP05_0044E','DP05_0057E','DP05_0071E']]

# %%
diver_state_df.head(5)
# Out:
#         GEO_ID                  NAME  \
# 0           id  Geographic Area Name
# 1  0400000US17              Illinois
# 2  0400000US19                  Iowa
# 3  0400000US29              Missouri
# 4  0400000US32                Nevada
#
#                                           DP05_0037E  \
# 0  Estimate!!RACE!!Total population!!One race!!White
# 1                                            9135145
# 2                                            2846099
# 3                                            5035197
# 4                                            1924976
#
#                                           DP05_0038E  \
# 0  Estimate!!RACE!!Total population!!One race!!Bl...
# 1                                            1793079
# 2                                             115137
# 3                                             704327
# 4                                             280385
#
#                                           DP05_0039E  \
# ...

# %%
diver_state_df=diver_state_df.rename(columns={'NAME': 'Area Name', 'DP05_0037E': 'White', 'DP05_0038E': 'Black/African American', \
                                      'DP05_0039E': 'American Indian & Alaska Native', 'DP05_0044E': 'Asian' , 'DP05_0057E': 'Some other race', \
                                      'DP05_0071E':'Hispanic/Latino'})
diver_state_df.head(5)
# Out:
#         GEO_ID             Area Name  \
# 0           id  Geographic Area Name
# 1  0400000US17              Illinois
# 2  0400000US19                  Iowa
# 3  0400000US29              Missouri
# 4  0400000US32                Nevada
#
#                                                White  \
# 0  Estimate!!RACE!!Total population!!One race!!White
# 1                                            9135145
# 2                                            2846099
# 3                                            5035197
# 4                                            1924976
#
#                               Black/African American  \
# 0  Estimate!!RACE!!Total population!!One race!!Bl...
# 1                                            1793079
# 2                                             115137
# 3                                             704327
# 4                                             280385
#
#                      American Indian & Alaska Native  \
# ...

# %%
# Merge Education by STATE with Diversity by STATE

# %%
state_edu_diver_df=pd.merge(edu_state_df, diver_state_df,on="GEO_ID")

state_edu_diver_df=state_edu_diver_df.drop(columns=["Area Name_y"])
state_edu_diver_df.head()
# Out:
#         GEO_ID           Area Name_x  \
# 0           id  Geographic Area Name
# 1  0400000US02                Alaska
# 2  0400000US23                 Maine
# 3  0400000US37        North Carolina
# 4  0400000US29              Missouri
#
#               Total_Population over 25 years old  \
# 0  Estimate!!Total!!Population 25 years and over
# 1                                         485353
# 2                                         983382
# 3                                        7102144
# 4                                        4182787
#
#                                  Less than 9th Grade  \
# 0  Estimate!!Total!!Population 25 years and over!...
# 1                                              12023
# 2                                              25361
# 3                                             305097
# 4                                             119915
#
#                             9th to 12th (no diploma)  \
# 0  Estimate!!Total!!Population 25 years and over!...
# ...

# %%
city_edu_diver_df.to_csv("city_final.csv", index=False)
state_edu_diver_df.to_csv("state_final.csv", index=False)
